# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

# %%
DEVELOPER_KEY = "AIzaSyA9MwabQALx7FUyRJERpS1R4LWjc1EEebQ"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)

# %%
#한 동영상 댓글 가져오는 함수
def get_comments(video_id, youtube):
    comments = list()
    response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()

    while response:
        for item in response['items']:
            
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append(comment['textDisplay'])

            if item['snippet']['totalReplyCount'] > 0:
                for reply_item in item['replies']['comments']:
                    reply = reply_item['snippet']
                    comments.append(reply['textDisplay'])

        if 'nextPageToken' in response:
            response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=response['nextPageToken'], maxResults=100).execute()
        else:
            break
            
    return comments

# %%
search_chanelname = '침착맨'

# %%
maxResults = 10 # 최대값 = 50

# %%
search_response = youtube.search().list(
    
    q = search_chanelname,          #검색어
    order = "date", 
    part = "snippet",
    type = 'video', 
    maxResults = maxResults
    ).execute()

# %%
recheck_name = []

for i in range(maxResults):
    recheck_name.append(
        {search_response['items'][i]['snippet']['channelTitle'] : search_response['items'][i]['snippet']['channelId'] }
    )

recheck_name = list(map(dict, set(tuple(sorted(d.items())) for d in recheck_name)))

# %%
recheck_name
# Out:
# [{'침착맨 플러스': 'UCC1LvVTX2ySKYjeIXkAtvsQ'},
#  {'쇼츠 100개 올리기 도전': 'UC85d2m3nAtMYoXQbEzF_5oA'},
#  {'조정근': 'UCI-4-Ah6d8nlg4kkJo1AcGg'},
#  {'하츠네미쿠의 소탐대실': 'UC40ry2rCj9KEM6UuMMZ_odQ'},
#  {'일일칠 - 117': 'UCWaWvDRyhmSKOQWah7t7wuA'},
#  {'침착맨': 'UCUj6rrhMTR9pipbAWBAMvUQ'}]

# %%
print('검색하신 채널이 맞나요? 맞는채널을 고르시오 사용자가 이름을 선택함')
# Out:
# 검색하신 채널이 맞나요? 맞는채널을 고르시오 사용자가 이름을 선택함

# %%
print('선택하신 채널명은 침착맨 입니다.')
# Out:
# 선택하신 채널명은 침착맨 입니다.

# %%
recheck_name[5]
# Out:
# {'침착맨': 'UCUj6rrhMTR9pipbAWBAMvUQ'}

# %%
search_response = youtube.search().list(
    
    q = '침착맨',          #검색어
    channelId = 'UCUj6rrhMTR9pipbAWBAMvUQ',
    order = "date", 
    part = "snippet",
    type = 'video', 
    maxResults = maxResults
    ).execute()

# %%
videoIds = []
videotitle = []
for i in range(maxResults):
    videoIds.append(search_response['items'][i]['id']['videoId'])
    videotitle.append(search_response['items'][i]['snippet']['title'])

# %%
comments = []
for videoid in videoIds:
    comments = comments + get_comments(videoid, youtube)

# %%
comments
# Out:
# ['츄리닝 그레이세트만큼 지능이 떨어져보이는 코디가 또 있었다니',
#  '어제 조밥대전에서도 주우재 레전드였는데 ㅋㅋㅋ 주우징',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=27m17s">27:17</a>',
#  '둘이 ㅈㄴ 잘맞넼ㅋㅋㅋㅋㅋ',
#  '초반 아조씨 니트 어디 껀지 아시는 분 ..',
#  '세레머니 개킹받네ㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=3m34s">3:34</a> 이게 왜 웃김? 빈폴 피식?',
#  '아잇!!! 겨울에 갑자기 웃어서 입술 찢어짐',
#  '이제 누가 찐착맨인지 헷갈려',
#  '방장이 2배? 오히려 좋아',
#  '개같이웃기네 ㅅㅂㅋㅋㅋㅋㅋㅋ',
#  '주우재 상병이 말년 병장의 비위를 맞춰주는 척 즐기는 모습이다.',
#  '채팅에 침혜련 밥먹다 죽을뻔 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '안 어울리는 듯 잘 어울리는 조합ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '하만카돈님은 이제는 더 이상 출연하지 않으시나요?',
#  '주우재 가라르폼',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=24m29s">24:29</a> 자세진ㅈ짜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅠㅠㅠㅠㅠ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m55s">8:55</a> 기안84랑 침착맨이랑 사이 안좋나요??',
#  '안좋긴요 ㅋㅋ<br>다만 기안과 똑같다고 하는것을 &#39;거부&quot;할 뿐입니다',
#  'Dk닠ㅋㅋㅋ아닠ㅋㅋㅋㅋ ㅋㅋㅋㅋㅋㅋ라이브얐냐곸ㅋㅋㅋㅋ 첨에 그냥 bgm인줄ㅋㅋㅌㅋㅋㅋㅋ',
#  '근데 둘이 왤케 잘 놈 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '클라스크를 보니 영화 공동경비구역jsa의 남북한병사가 노는 장면이 떠오르네요',
#  '아 진짜 미쳤다 ㅋㅋㅋㅋㅋㅋㅋㅋ 결이 같아서 더웃기넼ㅋㅋ',
#  '댄져러스맨 맨투맨 탐난다...',
#  '클라스크 대회 한번 열죠?',
#  '진짜 한참을 깝족거리네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ침아저씌 저 운동복 진짜 잘어울려요❤',
#  '인트로보고 뭔 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜 미친사람들',
#  'ㅋㅋ 재밌겠다',
#  '둘이 엄청 친해졌넹 보기좋다',
#  '그 발타치하는게 존나웃기단데 앖네ㅋㅋㅋㅋ',
#  '아니, 우재쿤 노래 왜 잘하는데',
#  '저게뭐야ㅋㅋㅋ',
#  '마지막에 가라 들키는게 개웃기네ㅋㅋㅋㅋㅋㅋ',
#  '충분히 발달한 우재쿤은 침착맨과 구별할 수 없다',
#  '킹받는 재미로 보는건가요?',
#  '약간 김도 감성인데 점점 ㅋㅋㅋ',
#  '두남자의 링피트? 이건 귀하다ㅎㅎ',
#  '저 초록색 가디건 어디 제품인지 아시는분 없나요? ㅜㅠ',
#  '침착맨 V넥 너무 선정적이야 ㅗㅜㅑ',
#  '비니색 말고 ㅈㄴ신경쓴거아니고 걍 걸쳤는데 옷핏 싼다ㄹㅇㅋㅋ',
#  '아 둘이 노는거 언제봐도 커여웤ㅋㅋㅋㅋㅋㅋ',
#  '힘든싱어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '철딱서니 없는 의좋은 형제같음ㅋㅋㅋㅋㅋ',
#  '침착맨 내복 뭔데여 ㅠㅠㅠㅠㅠㅋㅋㅋㅋㅋ',
#  '아 개재밌다 진짜 행복해',
#  '인생은 멀리서보면 주우재 가까이서 보면 침착맨이다.',
#  '우재쿤 모자쓰니까 아기공룡 둘리에 쭈꾸미왕자같음',
#  '진짜 개웃기네 ㅋㅋㅋㅋㅋ',
#  '거 준내게 깝치네 ㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋ모델스킨 침착맨 주우재',
#  '저사람들 왜저러는거야',
#  '다들 침착맨 보면 옷을 주고 싶은가봐<br>인간 의류수거함',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=27m21s">27:21</a> 우재님이 노래 부른 노래 제목 뭐에요?',
#  '@임동현감사합니다!!',
#  '김동률의 &#39;기억의 습작&#39; 입니다!',
#  '목걸이 센소라마 네요<br>이뻐서 찾아봤는데 45만원<br>못사..',
#  'ㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜 역대급…. 둘이 진짜 잘 맞아,, 최고의 조합 종나 웃겨~~',
#  '링피트는 뛰는게 개힘듬... 보스 공격하는건 재미라도ㅜ있지 뛰는건 하... 다리 더 올리라고 할때 욕나옴 ㅠㅜ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m30s">8:30</a> 어떻게든 꼭툭튀를 가리려고 자막으로 가리는거봐ㅋㅋ',
#  '카디건 브랜드가 뭔가요???',
#  '이건 진짜 침착맨 녹색박물관(플러스)가서 링피트 풀버전 버전으로 봐야함 ㅋㅋㅋㅋ 바칼 레이드로 스트레스받은 거 다풀렸음 ㅋㅋㅋㅋㅋㅋㅋ',
#  '아니 썸네일 미쳤냐고 ㅋㅋㅋㅋ 안누를수가 없다 ㅋㅋㅋㅋㅋㅋ',
#  '요즘 진짜 침투부 깔깔 거리면서 보는데 이번편도 진짜 ㅋㅋㅋㅋㅋ',
#  '아니 이 형들은 그만 이상해져도 되는데 왜 더더욱 이상해지는 거야 ㅋㅋㅋㅋㅋㅋ 따라가질 못하겠네 ㅋㅋㅋㅋ',
#  '존나 웃기다 ㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=7m57s">7:57</a>',
#  '미춋네 진짜ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '주우재 : 링피트 할때 건조된 진격의 거인이 달리는 것 같았음..',
#  '훗날 침착맨을 다룬 실화기반 영화 나오면 개방장 역은 박정민수가,기안은 우재님이 하면 되겠다',
#  '무친 침지섭 존잘맨....',
#  '둘 다 지능 존나 떨어져보이네 ㅋㅋㅋㅋ',
#  '착맨씨 사실 처음봤을때 옷 살짝 부담스러웟는데 이제 익숙해졌어요',
#  '주우재 미쳤네ㅋㅋㅋㅋㅋㅋ',
#  '병견TV 수위 실화냐? 진짜 레전드다...',
#  '아죠씨 왜 또 잘생겨지심...?',
#  '침착맨 처음에 입고나온 니트? 맨투맨? 정보 알 수 있을까요 ?',
#  '레전드다...',
#  '주우재님 비니 사용하니까 아픈사람같아요 ㅋㅋㅋ',
#  '우재야 잘싸라',
#  '너무 친해진 것 같아요 이제 멀어질게요',
#  '침저씨 쭈펄이랑도 링피트 해줘요잉~!',
#  '이거 보고 링피트 구매 완료',
#  '아진짜 개웃겨요ㅋㅋㅋㅋㅋㅋ ㅠㅠㅠ<br>레전드 갱신..우재님 이랑 편해져서 케미 극강이네 육성으로 깔깔댄거 오랜만이다',
#  '떡볶이 브랜드 아시는분???? 오징어 튀김 먹어보고싶어유',
#  '@뵤 감사합니다! 낼 시켜먹어야징',
#  '우리할매떡볶이 인 것 같습니당',
#  '주침 디스크 조각 추가에 감사하다...',
#  '이번건으로 올해의 인물 우재쿤…. 확실하다',
#  '와 이거 게임 어디서 사옄ㅋㅋㅋㅋㅋ',
#  '커닝시티 도적룩',
#  '아 썸넬부터 진짜 개욱기다',
#  '30분동안 웃음 아 개웃겨...ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㄱㅋㄱㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '주우재님 목걸이 어디 제품인가요??!<br>아시는 분 알려주세요 ㅠㅠ',
#  '썸네일보고 어떻게 안 들어올 수가 있냐 ㅋㅋ',
#  '아 웃다 토할거같애ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=10m21s">10:21</a> 침리머니 ㅋㅋㅋㅋㅋㅋㅋ 👂🤚<br><a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=16m02s">16:02</a>',
#  '그린 가디건 정보 좀요',
#  '아 <a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=23m06s">23:06</a> ㅈㄴ웃기네',
#  '둘이 주파수 맞아서 공명하는거 개웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '표현이 개웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '회색티 진짜 폭력적이다..',
#  '점점 친해지니까 케미 ㅈ대네',
#  '침꿈나무',
#  '아 혼자보기 아깝네 ㅋㅋㅋ',
#  'ㅋㅋㅋ좋아요를 안누를 수가 없네 ㅋㅋㅋㅋㅋㅋ',
#  '아개웃기네진짜 ㅋㅋㅋㅋㅋㅋㅋ❤❤❤',
#  '왜 내가 웃음과 동시에 킹받는거야 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '??이게 무슨영상이야',
#  '😂😂😂😂 아 진짜 왜 이렇게 우끼',
#  'ㄹㅇ 사랑에빠진것마냥 다 이뻐보이나보넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '뜬금없이 발라드? 발라드 뮤브 얘기하는데 그럴듯함..',
#  '짜증나ㅋㅋㅋㅋ 왜저래ㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=25m26s">25:26</a> 이게 합성이 아니라 라이브라는 게 미쳤다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '우재쿤 저 날 진짜 하루를 꽉꽉 채워주고 갔음ㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=12m35s">12:35</a> 죤니 잘생긴 노홍철 같음 ㅜㅜ',
#  '초록색 가디건 정보: 감마갤러리',
#  '나 진짜 방장의 모든걸 사랑할수 있을줄알았는데 꼭지 튀어나온 흥건하게 젖은 브이넥 히트택은 진짜 좀 힘들다…',
#  '존나웃기네 ㅋㅋㅋ 왜 이렇게까지 하는건데ㅋㅋㅋㅋ 그동안 웃기고싶어서 어떻게 참았답니까 ㅋㅋㅋ',
#  '더한놈이왔네',
#  '두분 처음 만난게 언제임??',
#  '아 주우재 넘 귀여봉... ㅠ🤍🤍🤍',
#  '와 회색 브이넥 티샤쓰 미치겠다 ㅋㅋㅋㅋㅋㅋㅋ',
#  '저렇게 많이 파진 티는 뭐냐진짜 ㅋㅋㅋ 어디서샀음 ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '링피트 진짜 개웃기네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진짜 미러전이라 역대급으로 웃으면서 본 영상이네요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 둘이 어쩜 저리 똑같은지 제목 너무 잘 지으심 ㅋㅋㅋㅋㅋㅋ 개 킹받아!!',
#  '인트로 한공간 맞죠?',
#  '미친 거 아니야  ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ 세리머니 할 때부터 어? 이거 엄대엄인데 싶었는데 챔피풘부터는 숨도 못쉬고 웃음 ㅠ 아놔 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ 드로아버님 자주자주 나와주셔요 너무 꿀잼임ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '주우재 뛰는 폼 다나카랑 개똑같네 ㅅㅂㅋㄱㅋㄲㅋㄱㅋㄱㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아 웃겨 죽어',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=16m42s">16:42</a> 반칙맨 검거',
#  '우재쿤 자주와줘 제발',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=7m09s">7:09</a> 직원 생각만 한다는 거짓부렁에는 안달리다가 우재쿤의 “블랙기업” 한마디에만 달린 자막..<br>침수자님들 안녕하시죠..?',
#  '초록색 가디건 어디껀가요..',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=13m28s">13:28</a> ㅋㅋㅋㅋ 아니 진짜 ㅋㅋㅋ 왜이렇게 유치함 ㅋㅋㅋㅋㅋ 진짜 웃겨 ㅋㅋㅋㅋ',
#  '주우재 일본 여학생이 지각해서 뛰는 것 같다는 글 본 후로 저 말만 떠오름ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '썸네일 진짜 폭력적이다',
#  '진짜 너무 꿀잼 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '침착맨이랑 최근이 친해진 사람 중에는 고속도로 가평 휴게소 에서 오줌 싸고 손 안 씻은 사람이 제일 죽 잘맞아 보였는데 주우재가 한 수 위네ㅋㅋㅋㅋ',
#  '우재님 진짜 개웃기네요 방송 자주 나오시면서도 분위기 안튀고 뇌절도 없고 최고입니다\U0001fae1\U0001fae1',
#  '주우재님 문제적 남자에선 진짜 멋있어 보였는데, 이정도까지 침성분으로 가득 차있으신줄 몰랐습니다... 클라스크 노가드와 링피트 진심으로 충격먹었습니다.. ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '맨처음에 주우재 가운데 서있을때 머리 잘린거봐 ㅅㅂ',
#  '와진짜 둘다 개열받게하네 ㅋㅋㅋㅋㅋㅋ',
#  '진짜 둘 다 개킹받음의 끝판왕이다.. 특히 주우재 링피트 뛸 때 오로나민씨 자세 너무 킹받아 흐느적거리는 광고풍선 그 인형 같음',
#  '근데 클락스는 특이해서 모를수가있나',
#  '이번 편 원본 못 보는 게 너무 아쉽지만 디스크 조각모음 하듯이 플러스 채널이랑 본 채널에 알뜰하게 긁어서 올려주는 거 좋다!! ㅠㅠ',
#  '댄저러스맨 저거 신상임?',
#  '이 인터넷방송 뭐냐고요ㅜㅋㅋ큐ㅠㅠㅠㅠㅠㅠ아 인트로부터 터져버리믘ㅋㅋㅋㅋㅋ',
#  '주우재 그는 금과 옥 같은 사람이다 ㅋㅋㅋㅋ',
#  '염병 소리가 절로 나오는 영상',
#  '진짜 우재쿤 미친거 같음 ㅋㅋㅋㅋ 개터졌네<br>준빈쿤에 이어 우재쿤까지 .....<br>개방장은 재밌는 사람이 모이는듯 럭키가이',
#  '침착맨 얼빠들 기강 빡시게 잡는 거 보소',
#  '18',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=23m08s">23:08</a> 아 오랜만에 침착맨 유툽 배꼽잡고 웃었네<br>주우재 하드캐리 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=23m34s">23:34</a> 채팅 침착맨 납치됐나요? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '인트로 비주얼 실환가....?',
#  '얼마만에 이렇게 실컷 웃어보는거냐 ㅋㅋㅋ 미쳤네 진짜 ㅋㅋㅋ',
#  '우재씨가 부른 노래 제목이 뭔가요??',
#  '이게뭐얔ㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=24m18s">24:18</a> ㅅㅂ 이게뭐람 진격의 거인 기행종 같아요',
#  '가라맨 ㅋㅋㅋ 침착맨 자리뻇길까봐 고군분투하네 ㅋㅋㅋ',
#  '방장 빈폴 모델이라고 괜히 까불거리는 거 왜이리 귀엽냐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 평생 빈폴 전속 모델 갑시다 ୧( “̮ )୨ ✧',
#  '오늘 슈룹보다가 침착맨 나오는줄 알았어요 매우 닮은 배우분 나오시던데ㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=17m27s">17:27</a> 아 여기부터 뇌운동 세모네모그리기 진짜 개웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '꼼수천재네',
#  '우재쿤 목걸이 정보점요',
#  '우재쿤이 침착맨한테 준 초록색 가디건 브랜드 감마갤러리 같아욤',
#  '그냥 럭키침착맨이잖아 ㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=7m29s">7:29</a> 내가 하지말라그랬자나~ 그게아니구~ <br>ㅇㅈㄹ ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '근래 본 모든 영상물중에 제일 웃기네 ㅋㅋㅋㅋㅋㅋㅋ',
#  '침착맨은 납치된 건가요?',
#  '다행이다. 그래도 원본은 아니지만 꽤 볼 만 한 거.시.다 . !',
#  '와 진짜 처음부터 끝까지 쉴 새 없이 웃음',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=20m00s">20:00</a>',
#  '아니 그래서 초록 가디건 어디서 살 수 있는지 ㅅ',
#  '감마갤러리',
#  '우재님 감사하다 💙',
#  '노래는 왜 잘부르누 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '개방장 브이라인 회색티 입고나올때 빵 터짐ㅋ<br>두번째는 링피트할때 회색티에 쫄바지 입고 🐕 킹받게 뛰는거보고 엄청 웃음ㅋ',
#  '이거 괜찮은데...?',
#  '그래서 초록색가디건 어디껀가요??',
#  '감마갤러리요!',
#  '제목이 거울치료인게 개웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '저 비싼 옷들 선물말고 우재쿤 흰티가 절실ㅜㅜ',
#  '인트로만 보고 웃어버렸네 ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ뻔뻔하게 잘함 거울치료 완벼크',
#  '불길 감지하고 바로 옆에 있는거 확인 안 하고 캠으로 확인하는거 너무 웃기네',
#  '아 꼭지보이는거 개 킹받네 참기 힘들다',
#  '위험한남자이병건티 개이쁘네',
#  '이정도면 풀버전 안 올라오는 이유 YG에서 막아서 그런거 아니냐? 이찬혁만 해도 벅찬데 주우재도 저러고 있으니까 손 쓴 듯 ㅋㅋ',
#  '조유진님 너무 좋아 ㅋㅋㅋㅋㅋㅋ',
#  '왼쪽! 오른쪽!에 박자 맞춰서 노래 부르는 모습은 그 어디에서도 볼수 없던 기이한 광경이네요.',
#  '그래서 저 초록색 가디건 어디껀가요?',
#  '@치치 감사합니다 🙏',
#  '감마갤러리용!!',
#  '아 진짜 송아지 달리기 미쳤나봐 쥰내 웃기네',
#  '우재 기억의습작 커버 올려주면 좋겠다… 개좋네',
#  '우재쿤 고체향수 목걸이 정보좀요…',
#  '아니 첨부터 너무 충격적이네',
#  '어디서 오신 선생님인지 몰라도 치료실력 대단하신듯ㄷㄷ',
#  '아 링피트 보면서 윗몸일으키기라도 해볼까 하면서 보고있는데 우재님 노래 부르는거 엄청 힘빠짐ㅋㅋ',
#  '정말 사랑 받는 침착맨...',
#  '주우재랑 이렇게 찐친될 거라고 생각도 못했네 진짜 ㅋㅋㅋ',
#  '목걸이:센소라마<br>가디건:아더에러',
#  '관종 싫어',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=6m23s">6:23</a> &quot;버벌침트&quot;',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=24m18s">24:18</a> 우울증 치료제',
#  '저 게이밍 슈트.. 손민수 각..?',
#  '근데 주우재는 메이저에서는 둘째가라면 서러운 광긴데 침이랑 있을 땐 찐광기 앞에서 가짜광기가 되는 2인자 포지션이라 더 웃김',
#  '으아니 뛸 때 왜 젖이 출렁이냐고요ㅠㅠㅠㅠㅠㅠ으악 내 눈.....',
#  '저 클라스크는 풀버전으로 봐야됨 ㄹㅇ 꿀잼임 ㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m26s">8:26</a> 조신한 이병건조기',
#  '주우재하고의 케미는 또 결이 다르네 침착맨은 참 관계를 유연하게가져가네',
#  '목걸이 어디꺼에여?',
#  '진짜 소인배들ㄷㄷㄷ',
#  '초록색 가디건 어디껀가요 ㅠㅠㅠㅠㅠ',
#  '감마갤러리용!! ㅠㅠㅠㅠㅠ',
#  '아이 리씹 더 더블 킹',
#  '초록색 가디건 그런데 어디껀지 아시는 분',
#  '감마갤러리',
#  '그래서 가디건 대체 어디꺼임…????',
#  '감마갤러리용!!',
#  '진짜 썸네일부터 개웃기네ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '침착맨 만나려면 50만원 상당의 옷과 신발은 기본이구나...<br>모델이라 저렴하게 구매하시거려나...<br>옷 너무 이쁜데 학생이라 맘대로 못사입는 입장에서 넘모 부럽당 ㅎㅎ',
#  '안녕하시렵니까',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=31m50s">31:50</a> 아 개웃기네..',
#  '아저씨덜 대체 몇살이야…ㅋㅋㅋㅋㅋ',
#  '빈폴이 방장 모델로 쓴 이유가 있구나 바지 겁나 이쁘다 ㅋㅋㅋㅋㅋㅋ',
#  '우재형이 부른 노래 제목 머더라???',
#  '아니 근데 침착맨은 그렇다 쳐도 어떻게 시청자들이 브라운야드 세터 아더에러를 난생 첨 들어..?? 말이 됨?? 진짜 방구석에 처박혀서 인방만 봄????',
#  '옷에 관심없으면 모르는사람 많음',
#  '으음 모를수도 있을거 같은데요…?',
#  '모를수도 있지 왜그래...',
#  '나는 지독한 얼빠였구나를 깨닫게 해주는 영상',
#  '침순이들 정신 못 차리는중 ㅋㅋ',
#  '둘이 왜케 잘맞앜ㅋㅋㅋㅋㅋ간만에 현웃 제대로 터졌네 ㅋㅋㅋㅋㅋ주우재님 그와중에 노래도잘하네;',
#  '지하철에서 보다가 웃음 터질것같아서 영상 멈췃다,,,집가서 봐야지 ㅋㅋㅋㅋㅋㅋㅋㅋ아 브이넥 티 입은 개방장만 봐도 웃기네',
#  '그 와중에 왜 감미롭고 난리 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '30분내내 진짜웃기다 ㅋㅋㅋㅋㅋㅋ',
#  '세레머니 하지말라매~~~~',
#  '주우재👍',
#  '와 진짜 개 킹받아 와 지나ㅉ',
#  '개잘생겻어 주우재ㅜㅜ 옷도 너무 잘입고 항상 차분한데 말도 재밌게해서 너무좋아ㅠㅠㅠㅠ',
#  '실친이었음 일찌감치 손절치고 연락도 안할 성격인데 이제는 챙겨보지 않으면 인생의 뭔가 큰 과제를 안한 느낌이 든다…',
#  '우재 형 침한테 얼마 받은 거야 대체...',
#  '진짜 속이 꽉찬  영상이닼ㅋㅋㅋ 킬포가 몇개얔ㅋㅋㅋㅋ',
#  '옷들이 다 몇십짜리인데 그냥주네 우재클라스..',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=6m12s">6:12</a> 가디건 어디껀지 아시는분',
#  '감마갤러리',
#  'ㅇㄷ',
#  '우재군 왤케 웃겨 ㅋㅋㅋㅋ',
#  '둘이 결이 너무 잘맞앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 세레모니할때 개웃김 진짜',
#  '우재쿤.. 침착맨을 사랑한 죄로..',
#  '초록색 가디건 어디껀가요???',
#  '감마갤러리',
#  '우재쿤이 아무리 분발해도 킹받기는 역시 우리 아조씨가 제일이군😊',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=16m42s">16:42</a> 여기서 부터 간만에 진짜 존나 웃었네 ㅋㅋㅋㅋㅋㅋㅋㅋ <br>침착맨이 두명이 되니까 개웃기다 아 ㅋㅋㅋㅋ<br>약간 옛날 아프리카때 감성 보는듯',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=12m22s">12:22</a>',
#  '히히 조합 너무 보기 좋다 🖤\U0001fae7🖤 <br>(주우재님 고체 향수 목걸이 오디꼬래요????)',
#  '센소라마',
#  '아니 브이넥 부터 1초마다 웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ<br>아 ㅅㅂ 진짜 주우재 눈물나게 웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ<br>진짜 주우재 준빈쿤 김풍 셋에 밀려서 궤도님 이름도 못올릴듯 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '주우재님 원펀데이 참여 부탁드립니다🙏',
#  '복장 너무 귀여움 ㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=13m26s">13:26</a> 갑자기 앞머리 말아주는거 개웃곀ㅋㅋㅋㅋ',
#  '아 진짜 개웃겨ㅠㅠㅠㅠㅠㅠ',
#  '제목은 거울치료지만 그저 킹받음이 두배로 늘어날뿐이고 치료효과는 없는듯 ㅋㅋ',
#  '생긴 건 멀쩡하게 생겼는데 둘이서 개유치하게 노는 고딩들 보는 거 같다<br>맨날 둘이서 이상한 놀이 만들고',
#  '우재쿤 갈수록 쇠약해지는거 개웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=07m59s">07:59</a> 아니 방장 갑자기 ㅋㅋㅋㅋ',
#  '아 짖짜 웃겨서 너무 짜증나',
#  '진짜 어쩜 저렇게 말투가 비슷햐 ㅋㅋㅋㅋ',
#  '주우재도 보니까 보통 또라이가 아님ㅋㅋㅋㅋㅋㅋ',
#  '침착맨 vs. 침착맨',
#  '아진짴ㅋㅋㅋ 기행종뛰는줄 ㅋㅋㅋ,,ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '둘이 진짜 어떤 부분에선 되게 다른데 엄청 비슷하다니까 ㅋㅋㅋㅋㅋ',
#  '골 킹받아',
#  '큰거왔다',
#  '근데 이 방송보니깐 우재쿤도 나이 든 티가 보인다...ㅋㅋㅋㅋㅋㅋㅋ',
#  '근데 주우재님 노래 왤케 잘함? 깜짝놀랬네',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=13m27s">13:27</a> 침고생',
#  '골넣고 염병떠는거 개웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=08m55s">08:55</a> 아니 우재님은 침과 기안이 결이 같다고 했지만... 본인도 어느면에서는...(말끝까지 다 안함)<br><a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=28m59s">28:59</a> 포켓몬스터에서 본거같은 우재',
#  '저거 초록색 가디건 종류 아는 사람 있으시면 부탁드립니다❤',
#  '저도 궁금 ㅠㅠ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=10m34s">10:34</a> 방장 덮은머리 진짜 너무 잘 어울려..사랑행 ..',
#  '저분이 2대 침착맨이신가요?',
#  '댓글 자꾸 삭제 당해 ㅜㅜ 세레모니 타임라인 올리는데',
#  '진심 레전드화.... 개재밌음 ㄹㅇ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=6m12s">6:12</a> ㄹㅇ 잘어울린',
#  '아 진짜 개웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '이게 시트콤이지',
#  'ㅅㅂ나도 우재같은 친구 갖고싶다',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=21m39s">21:39</a> ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=18m36s">18:36</a> 편집되서 짧게 나오지만 저 덜렁거리면서 하찮게 추는 도발춤 30초 넘게 춤ㅋㅋㅋㅋㅋㅋ',
#  '저거 초록색 가디건 어디꺼지',
#  'ㅇㄷ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=2m29s">2:29</a> 선물 받아서 기분 조은 침아조씨 커엽,,,',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=24m16s">24:16</a>',
#  '하지ㄴ짜 개읏기닼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 이번꺼 ㄹㅈㄷ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=19m07s">19:07</a> <br>3개가 서있네요',
#  '대박',
#  '주우재님이 노래 부르는거 제목 혹시 어떤거가용?',
#  '@채똥이 엇 기억의 습작 전에 부른 노래 알수있을까요?',
#  '기억의 습작 김동률',
#  '야이c 썸넬ㅋㅋㅋㅋㅋ좀전에 ‘오늘의 주우재’ 보고 멋지다 하고 있었는뎈ㅋㅋㅋㅋㅋㅋㅋ<br>(‘모델 주우재’와 링피트 ‘다나카 우재’의 킹받는 극명한 온도차❤)',
#  '침착맨 진짜 내동생 닮았어..<br>주우재 노래잘하네',
#  '클락스 왈라비 나 다시 사고 싶었는데 주우재 신는거 보고 결심🎉',
#  '우재 웃기게생겻넼ㅋ',
#  '존나웃곀ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '저 축구 보드게임 어디서 사나요 넘 재밌어보임!',
#  '미친사람 같아서 너무 보기 좋네요',
#  '우재형 노래 왜케 잘함?',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ봐도 힐링❤',
#  '하.....',
#  '우재쿤 코디에서 토니웩이랑 아더에러는 아는나 칭찬해',
#  '아 링피트 브금넣는거 개욱기넼ㅋㅋㅋㅋㅋㅋ',
#  '침하고 주랑 서로 말 놓기로 함? 침 계속 반말 쓰네 서로 친해져서 놓은건가',
#  '우재쿤 고정으로 나와줘잉 개웃기고 둘다 너무 귀여움 ㅋㅋㅋㅋㅋ',
#  '우리힌테는 이게 무한도전이지',
#  '아 웃다못해 울면서 보네 ㅋㅋㅋ미친 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㄲㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '괜스레 비싼선물받는거 부담스러워서 오히려 막대하는거 열받네',
#  '군용 사각런닝이라기에는 색깔이 묘하게 다르네',
#  '올해 웃은것 중에 제일 크게 웃었네ㅋㅋㅋㅋㅋㅋㅋ<br>어질어질하다 ㅋㅋㅋㅋㅋ',
#  '침착맨 저날 바지 정보좀요 ㅠㅜㅜ',
#  '초반에 토크할때..',
#  '아무리 웃겨도 턱아픈적은 처음이네 진짜 하남자들같아서 개웃김',
#  '세레모니 미쳤나 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 일요일 개콘느낌이네 ㅋㅋㅋㅋㅋ 아 재밌다 ㅋㅋㅋㅋㅋㅋ',
#  '기행종이래 미치겠다  ㄲㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㄲ',
#  '밥 먹으면서는 보기 힘드넼ㅋㅋㅋㅋ ㅠ',
#  '야꼭지도 본 사인데 이정도 옷 쯤이야 뭐..',
#  '뭔가.. 둘다 외동인데<br>명절 때 사촌 만난 것 마냥 <br>철없이 잘노네ㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=17m45s">17:45</a> 부터 침염병의 시작 혼자 랄지발광임 움직이는 거 킹받아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '링피트 영상만 계속 돌려보는중ㅋㅋㅋㅋㅋㅋ둘다 달리기 개킹받음 <a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=20m41s">20:41</a>   <a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=24m18s">24:18</a>',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=19m13s">19:13</a> 거울치료 시작ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=25m25s">25:25</a>',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=9m20s">9:20</a>',
#  '우재님 침맨 옷입히기 즐기시는 듯 ㅋㅋㅋㅋㅋ근데 나도 대리만족된다 ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ30분 개알차네',
#  '개방장 앙탈부리는거 존나 사랑스럽네',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=2m58s">2:58</a> 순간 반스신고 헤이마마 추려는줄ㅋㅋ',
#  '야랄하네 진짴ㅋㅋㅋㅋ',
#  '썸네일부터 어이없엌ㅋㅋㅋㅋㅋㅋㅋㅋ진짴ㅋㅋㅋㅋㅋ',
#  '보면 볼수록 드는 생각: 주우재 침착맨 존나 좋아하능구나..',
#  '침착맨을 치료하는 걸까 역준빈을 치료하는 걸까...',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=3m48s">3:48</a> 여기부터 소파까지 가져가 이부분 카와이이 하네요이',
#  '침펄풍 다음으로 재밌다 진짜 아 배아프고 입아프고 미쳐',
#  'ㅋㅋㅋㅋ진짜 개존잼ㅋㅋ',
#  '이게 37세와 40세...?',
#  '싱글벙글 난장판',
#  '아진짴ㅋㅋㅋㅋㅋ 이 둘이 세상에서 제일 웃곀ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아 진짜 너무 웃기네',
#  '가장 놀라운 것은 주우재랑 침착맨이랑 3살차이밖에 안 난다는거..',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=21m39s">21:39</a> 아 진짜 개열받네 주우재',
#  '주우재님 모자쓰시니 둘리에 꼴뚜기왕자 같네요;; ㅎㅎ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=19m52s">19:52</a> 침아조씨의 매직마이크',
#  'zㅋㅋㅋㅋ주우재 런닝맨에서 개털리는거 재방으로 보다가 트수담당일진노릇하는거보니까 인지부조화오네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '주의! <br><br><br>수염많은 거인과 전봇대 거인이 나옵니다',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=4m05s">4:05</a>',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=20m10s">20:10</a> 체한 주우제',
#  '주우재는 그냥 쥰내 잘샐기고 옷 잘입는 침착맨이구나 ㅋㅋㅋㅋㅋ',
#  '초록색 가디건 브랜드가 어디꺼인가요?',
#  '아니 ㅋㅋㅋ 썸네일을 이따구로 만들면 어떻게 안들어오냐고요오오옼ㅋㅋㅋㅋㅋㅋ',
#  '아...............너무 웃어버려 킹받누........편집자님이 살린거라고 확신한다....',
#  '썸넬 하ㅜㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '미친 고체향수 목걸이 45만원ㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=10m22s">10:22</a> 존나 커여워 ,,, 근데 착맨 바지 존예,,ㄹㅇ루',
#  '이게 뭔방송임 대체ㅋㅋㅋㅋㅋㅋㅋ저 옷은 뭐고 감미로운 노래는 뭔뎈ㅋㅋㅋㅋㅋ혼란하다 혼란하',
#  '아니 저 히오스바지 왜 아직도 가지고있음?ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진짜 썸네일 개폭력적이네 ㅋㅋㅋ',
#  '그래서 누가치료되고있는거죠..?',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m55s">8:55</a> 기안 님 이야기 나올 때 초점 흐릿한 게 웃김 ㅋㅋ',
#  '티파니에서 터졌네',
#  '거의 원초적인 웃음벨이닼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진짜 개웃기네ㅋㅋㅋㅋㅋ',
#  '혼-돈',
#  '주우재 그냥 침착맨 사촌 같음ㅋㅋㅋㅋㅋ',
#  '침착맨 왜케 잘생겼냐구우우우우우 ㅜㅜ 내의를 입어두 잘생겨땨규',
#  '진짜 너무웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '세레머니야 벌칙이야 ㅋㅋㅋ',
#  '무친주우재 ㅋㅋㅋㅋㅋㅋ 이런사람인지 알고있었는데 이정도 일줄도 알고있었음 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=5m54s">5:54</a> 마지막 남은 가디건 제가 사갑니다',
#  '어디건가요?',
#  '어디껀가요,',
#  '빈폴 광고로 유입된 얼빠 개청자들 기강잡기.. 이게 개방장이지',
#  '그 와중에 세모그리기 네모그리기는 왜 잘해?ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '우재쿤이랑 같이 있는 분위기 더 편해졌네 ㅋㅋㅋㅋㅋㅋ 좋다 좋아',
#  '@ᄌᄒᄋ 30대 후반이고 3살차이니 거의 친구먹은듯 ㅋㅋ',
#  '이제 반말을',
#  '뭔가 요즘 침착맨이랑 친해진 사람중에 가장 잘놀아주는듯 ㅋㅋㅋㅋㅋ',
#  '초딩때 필통게임기하면서 개많이싸웠을듯 ㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=10m32s">10:32</a> 개웃기다 진차',
#  '침착맨 옷 왜캐 잘입엇져 설레자냐',
#  '입술을 깨물쥬 또 발끝만 보쥬 킹받쥬 아무거토모타쥬',
#  '침투부 수위 실화냐;;',
#  '통천 이후에 침착맨 거울치료 가능한 사람이 나올 줄은.. 거기다가 그게 주우재님일 줄은 상상도 못했네 ㅋㅋㅋㅋㅋㅋㅋㅋ 침니버스 확장되는 거 너무 신기해잉',
#  '고체향수 목걸이 어디 꺼에요????',
#  '센소라마',
#  '우재형 진짜 감 다살았네ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '세리모니 너무 길게 하니까 역버피오목 느낌나서 위화감 오지네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ😊',
#  '와미친개열받아 와 ㅋㅋㅋ',
#  '어린 침착맨이 주우재라고 생각했는데<br>남지 통천이 주우재가 아닐까 싶음 ㅋㅋㅋㅋ<br>자꾸 뭘 들고와 ㅋㅋㅋㅋㅋㅋ',
#  '둘이 친해지니까 더 재밌넼ㅋㅋㅋ',
#  '추함 경연대회 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '유치한데 개웃겨 ㅋㅋㅋㅋㅋ',
#  '우재쿤 하입보이도 잘추더니 노래도 잘하네?',
#  '저거 에어하키 보드게임 이름 뭔지 알려주실분... 개탐남 ㄹㅇ..',
#  '저두염-!',
#  '하여간 진짜 개잘한다니깐',
#  '레전드네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '복제인간이랑 사이좋게 노는 모습같아서 무서워요...',
#  '개처웃어서 머리아프다',
#  '아니 이 사람 왜 이렇게 된거야',
#  '둘이 결 ㅈㄴ 비슷함 그냥',
#  '자의가 아닐까요? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 자위라뇨',
#  '진짜 똑같은 사람끼리 서로 킹받아하는게 너무 웃김ㅋㅋㅋㅋㅋㅋ',
#  '주시경 ㅅㅂ ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '중년들이 이러케 귀여워도 되는거냐',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=24m17s">24:17</a> 누가 기행종이래ㅋㅋㅋㅋㅋㅋㅋㅋㅋ<br>미쳤나봨ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '요거올려주신거면 원본박물관에도 올려주셔도될거같은데 이날 넘웃겼음ㅋㅋ',
#  '@보초개 아 확정이예요? ㅠㅠ',
#  '이거 빈폴계약때매 원본 안올라간대요',
#  '저 잘생긴 외모와 기럭지를 가지고도 망가지는데에 서슴치않는 모습이 너무 매력있음ㅋㅋㅋ',
#  '우재쿤 왠지 미노이 오빠일 거 같음 둘이 유전자 검사해보셈 피 섞여있을지도 모름',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=19m10s">19:10</a> 침착맨 마이크위치가 너무야함',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=6m45s">6:45</a> 배방구',
#  '초록색 가디건 대체 어디건가요 ㅠㅜ??',
#  '두사람.. 뭔가 결이 비슷한거 같아....',
#  '근데 옷 잘어울린다ㅋㅋㅋㅋㅋㅋ',
#  '아니 침맨옆에있으니까 왜 꼴뚜기 왕자가됨',
#  '진짜 개판이네',
#  '우재야 잘싸라!',
#  '목걸이 이쁜데 먼지아시는붕~',
#  '센소라마',
#  '진짜 방장 옷이 개혼란스러움ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '갑분 노래 개웃기네ㅋㅋㅋ',
#  '진심 페이커랑 침착맨이랑 축구 겜 하는거 보고싶다',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=25m27s">25:27</a> 개열받넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ ㅋㅋㅋ',
#  '내 살다살다 이상한 쫄쫄이 입은 브이넥아저씨가 괴이한 몸짓으로 링피트 하는동안 웬 패션모델이 옆에 앉아서 진지한 표정으로 감미로운 발라드 부르는 광경을 보게될줄은 몰랐다',
#  '진짜 세기말 감성임 ㅋㅋㅋㅋㅋㅋ',
#  'ㅠㅠㅠㅠㅠㅠㅠㅠㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '글로 써놓고 보니 진짜 기괴하네 ㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아진짜너무웃김 ㅠㅠㅠ',
#  '엠비티아이 과몰입충인데 잇팁으로서 주우재가 침착맨 어지간히 좋아하나 봄 까불까불 하는 걸 보니 저런 모습 아무나 안보여줌',
#  '제일 웃긴 운동이넼ㅋㅋㅋ',
#  '염병대잔치 ㅋㅋㅋㅋㅋㅋㅋ',
#  '근데 우재씨 친해져서 쑥스러워서 그런지 일부러 팬으로서 설레는 티 안 내려고 하는 거 같음ㅋㅋㅋㅋ',
#  '아니 침착맨 링피트 옷 너무 충격적임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '힘든싱어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=25m25s">25:25</a> ㅋㅋㅋㅋㅋㅋ노래 실화냐곸ㅋㅋㅋㅋ다른 차원인줄 알았네',
#  '이 영상이랑 침착맨플러스 채널에 편집본으로만 올라와있고 원본이 없어서 볼 수 없는 장면들이 너무 아쉽다…',
#  '저 고체향수목걸이 어디꺼이??',
#  '@장준희 너무좋고',
#  '센소라마',
#  '주우재에게 침착맨 출연은 일인가? 아니면 취미인가 ㅋㅋㅋ 진짜 표정은 저래도 겁나 즐기는게 보임 ㅋㅋㅋㅋㅋ',
#  '@esther 네 수정했습니다.',
#  '출연...출현은 외계인 출현! 할 때 쓰는 말',
#  '우재쿤… 당신의 링피트가 인스타그램을 정복하고 있는 것을 알고 있나요…? ㅋㅋㅋㅋㅋ',
#  '빨래 잘못돌려서 회색된 침착맨의 에어리즘 난닝구',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=30m16s">30:16</a> 이런 말 하면 안되는데...우재쿤 진짜 등짝 한대만 차지게 때리고 싶다 너무 열받음',
#  '대단한 건전함이다……ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아 너무 웃김',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=18m50s">18:50</a> 전설 시작',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=23m10s">23:10</a> ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '저 보드게임 정보좀주세요 아시는분~',
#  '@chhh 감사합니다',
#  '클라스크라고 쳐보시면 나옵니다~',
#  '둘이 진짜 개재밌네 노네 ㅋㅋㅋㅋㅋㅋ',
#  '아들 둘이 노는 것 같어ㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=3m26s">3:26</a> 빈폴ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아니 이정도면 할매떡볶이에서 피피엘 방장한테 하나줘라. 떡볶이 시켜먹으면 거의 할매떡볶이 먹더라. 보고 나도 영업당함',
#  '옷빨 은근히 잘 받는거 개킹받넼ㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=13m51s">13:51</a> 심지어 우재스코어도 조작해놨었음 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ야비맨',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=13m37s">13:37</a>에 우재씨 본인이 건들어서 옮겨짐ㅋㅋㅋ 방장은 아무짓도 안했는데 조작맨됨ㅠㅋㅋ',
#  '요즘 침튜브 썸네일만 봐도 웃겨죽을거 같음',
#  '우재쿤 인방이 뭐라고 안사리고 미친듯이 구르는거 조금 감동받을지도 ㅋㅋㅋ',
#  '이거 원본 박물관에 있던거 왜 지워졌나요? ㅠ.ㅠ',
#  '테이블 하키 세레모니 주우재도 만만찮네ㅋㅋㅋㅋㅋㅋ 개열받아',
#  '링피트 레전드넼ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '주우재 이제 침착맨 사단 된건가 자주나오네',
#  '기안과 주우재 사이 그 어딘가',
#  '침착맨 발등 탄거임?',
#  '2 ask man',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=24m18s">24:18</a> 거인인줄',
#  '진짜 세레모니 미쳤네 ㅋㅋㅋㅋㅋ',
#  '나몰라 패밀리인지 알았네',
#  '주우재가 운동을 하다니…이건 진짜 사랑임에 분명하다 폭력적인 사랑 응원합니다',
#  '우재형님이 참 착하다..',
#  '무슨 저런 옷이 있냐',
#  '우재쿤 왜 (전)8수자 닮은거같지',
#  '한 영상으로 몇 가지를 즐길 수 있는거얔ㅋㅋㅋㅋㅋ 가성비 쥑이네',
#  '헌 옷 왜 침한테 버리냐구',
#  '우재님 목걸이 정보좀요',
#  '@장준희 감사합니다',
#  '센소라마',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ 무슨 조합이예요..ㅋㅋ',
#  '진짜 킹받는다',
#  '오늘따라 비주얼 폭력적이네 정말..',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=12m40s">12:40</a>',
#  '진짜 우재님 뭔가 친한친구네 집에서 지 편하게 노는 것처럼 노신거 같아서 너무 편하게 웃으면서 봤어요 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '지편하게 ㅋㅋㅋ',
#  '썸넬봨ㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=16m45s">16:45</a> 진짜 개웃기네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '와...진짜 이런말하면 그렇지만 왠갖 염병은 다 떠시네ㅋㅋㅋ',
#  '역대급ㅋㅋ 풀버젼도레전드임',
#  '둘이 안어울릴줄 알았는데 엄청 잘 맞는다ㅋㅋㅋㅋㅋ',
#  '채팅창에 &#39;개싫어&#39; 가 제일 많이 올라온 날이 아니었을까 ㅋㅋ<br>그와중에 춤잘추는 방장이랑 그와중에 노래 잘부르는 주우재 뭐냐고 ㅋㅋㅋ',
#  '세레모니 왤케 노홍철같냐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '역사상 브이넥 입은 사람 중에 제일 꼴보기 싫음',
#  '둘이 왜이렇게 잘 어울리나했더니 거울이라 그랬구나...',
#  '몸뚱이 팔랑거리는거 개웃기네 ㅅㅂㅋㅋㅋㅋ',
#  '고체향수 목걸이 검색해도 안나오는데 어디껀지 아시눈분 있나요???',
#  '둘 다 너무 좋았는데 싫어질라 그래 처음으로…… ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '침착맨님 눈만 아래로 처지신 줄 알았는데, 가슴에 있는 눈 꼬리도 많이 쳐지신 줄 오늘 알았 …',
#  '미친ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ진짜 오랜ㄴ만에 얼굴근육 땡기게 웃었넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '우재쿤..ㅋㅋㅋㅋㅋㅋㅋ',
#  '방장이 일부러 빼달라 한건가 웃긴 포인트들 많이 날라갔네 ㅠ',
#  '개잘어울리누..',
#  '어뜨케 어른이 저렇게 수치심이없지 너무 좋다😂😂',
#  '침착맨 후계자 양성중?',
#  '하의와 상의 둘 다 킹받게 하는 그는..!',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '둘이 너무 잘어울려 진짜 넘 좋아요 이조합',
#  '아니 침저씨 본인한테는 거울치료지만 보는 우리들한텐 뭐든 2배인걸.....',
#  '역대급으로 킹받는 영상ㅋㅋㅋㅋㅋ',
#  '뭐하는방송이얔ㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '둘다 멀쩡히 잘생긴게 제일 열받음',
#  '브라운야드 토니웩 아더에러를 침저씨 방송에서 볼수있다니... 고맙다 패션민수야',
#  'ㅋㅋㅋㅋ주우재가 나오네??? 조합신선한데 ㅋㅋㅋ',
#  '세레모니킹받앜ㅋㅋㅋ',
#  '뭔가 중급으로 잘매치했에',
#  '그래서 저 고체향수 목걸이 어디거예요ㅠㅠ',
#  '센소라마',
#  '떡볶이 어디 떡볶이인가요??',
#  '할매 떡볶이래요',
#  '이건 원본이 없나요? 아시는분',
#  '@Gunwoo Lee 그럼 다시 생기는거에요?',
#  '폭파됐어용',
#  '방장 옷 갖고싶어..... 탐나.... 역시 위험한 남자',
#  '둘아 잔짜 똑같다 아 ㅋㅋㅋㅋㅋㅋㅋㅋㅠ 안만났으면 어쩔번봤어',
#  '잘생긴 사람 둘이 개웃기네 ㅋㅋㅋㅋㅋ',
#  '주우재 생각보다 더 이상한 놈이구나…',
#  '진짜 누르는 걸 참을 수가 없는',
#  '썸넬만 봐도 웃음이 나는 개방장과 우재쿤',
#  '침착맨 저렇게 행복해하면서 빡쳐있는거 첨봄ㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=18m27s">18:27</a> 랑종.....엑소시즘',
#  '이썸넬이면 밥친구 쌉가능<br><br>밥먹고 있는데, 틀자마자 똥....ㅎ',
#  '웰케 티키타카가 아빠랑 아들같짘ㅋㅋㅋ',
#  '주우재 뛰는거 보고 이것보다 더 웃기게 뛸 수 없겠다 싶었는데 침착맨은 더 웃기네ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '헐. 인트로가 합성이 아니었다?!',
#  '침착맨 주치의 오셨다',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=12m25s">12:25</a>개킹바단ㅋㅋㅌㅋㅋㅋㅋ',
#  '방장 운동복 왤케 숭해ㅋㅋㅋㅋㅋㅋㅋ',
#  '인트로 무슨 상황인지 진짜 감도안와',
#  '진짜 무슨 고딩친구 앉아있는거같음',
#  '옛날 노래방 뮤비 저렇지 않나 근데 ㅋㅋㅋㅋ 발라드 부르는데 에어로빅 같은 거 추고 있고 ㅋㅋ',
#  '주우재 클라스크 이기고 개방장 거울치료 제대로 되게 쫑알쫑알 지자랑 설교하는게 ㄹㅇ 웃겼는데ㅋㅋㅋㅋㅋ',
#  '빈폴 바지 진짜 핏 이쁘네',
#  '와 역대급으로 볼거리많다ㅋㅋㅋㅋㅋㅋㅋ<br>주가침좋아하는만큼 침도 주좋아하는게보여서 너무 흐뭇해',
#  '침멘의 더러운 보디 !',
#  '쭈우재님 재밌는 사람 정도라고만 생각했는데 개웃긴 사람이었넼ㅋㅋㅋㅋㅋㅋㅋ ㅁㅊ ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '왼쪽 오른쪽 왼쪽 오른쪽 오,,쪽 오ㄹ쪽,,,  쪽,, 쪽 ,,,쪽 ,,쪽,,,',
#  '거울 치료ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=25m26s">25:26</a> 힘든싱어 ㅋㅋㅋㅋㅋㅋㅋ',
#  '우재님은 여기오는게 너무 즐거워보여서 보는사람도 즐거움',
#  '둘이 너무 편하게 잘 놀음ㅋㅋㅋㅋ',
#  '아 주우재 넘좋아 ㅋㅋㅋㅋㅋㅋ',
#  '아니 왜 제목이 거울치료인가 했네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '&quot;가라왕 주우재&quot;',
#  '우재쿤 링피트하는거 진짜 개열받아',
#  '아 진짜 ㅋㅋㅋ 배째지게 웃었네',
#  '우재쿤  퇴사한 8수자님이랑 좀 닮은것같음',
#  '초록가디건 정보좀주세요!!',
#  '제발 ㅠ',
#  'ㅇㅈ',
#  '왕위계승 결정체',
#  '침형.. 외모로 안꿀리는거 봐..',
#  '우리 방장 사람들이 존잘맨이라 해서 화가 많이 났었나 보네',
#  '주우재 준빈쿤 옷 추천 언제 해주나',
#  '멀쩡하게 생긴....아니 잘생긴 사람 둘이서 개뻘짓하는 영상....귀하다',
#  '기안이형 .. 병건씨 좋은사람 생겼대.. 이제 그만 놔줘...',
#  'ㅋㅋㅋㅋ',
#  '아니 근데 주우재님 진짜 본업 존잘이네 ㄹㅇ 침착맨한테 딱 맞는 아이템들 너무 잘 가져옴',
#  'G DRAGON KING ,,,',
#  '근데 왜 저렇게 뛰는 거에요?',
#  '참 저 이쁜 댄저러스맨 니트를 두고 초라한 브이넥으로 방송하는 방장은 대체...',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=20m38s">20:38</a><br><a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=21m38s">21:38</a> <br>주우재가 미래다',
#  '개빵터졌다 진짜미친것같음ㅋㅋㅋ',
#  '인트로왤케킹받죠 미쳣다',
#  '이게 드디어 올라오네 ㅋㅋㅋㅋ',
#  '저 덴져러스맨 니트 판매하는건가요…? 아시는분… 너무 이뻐서 사고싶음 ㅠ',
#  '@정강환 그쵸 못찾겠어요ㅠ 그치만 감사합니다',
#  '저도 궁금해서 계속 찾아봤는데 없는거 보니까 미발매 상품 침착맨님 먼저 입으신거같아요',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m05s">8:05</a> 주우재 &quot;어우씨&#39; 모먼트',
#  '주우재님 오늘따라 보자마자 슈말코가 떠올랐어요',
#  '주우재도 가만히 보면 그렇게 못이길 정도로 잘생긴건 아닌듯.',
#  '2대 침착맨은 정해졌으니 행여나 털보가 &quot;번아웃&quot; 중독에 걸려서 은퇴하더라도 걱정은 없겠네요~',
#  '진짜 2배로 열받네 진짜 ㅋㅋㅋ',
#  '주우재형이 이렇게 웃겼었나 ㅋㅋㅋ 매력터지네ㅋㅋㅋㅋㅋ 두분 케미 지리네요',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=26m10s">26:10</a> ㅋㅋㅋ합성이냐 댓글 ㅈㄴ웃기네',
#  '초반에 면바진지 청바진지 옷빨좋다 했는데, 운동할때 타이즈인지 내복인지 안구테러네 ㅋ',
#  '세레모닠ㅋㅋㅋㅋㅋㅋ주우재가 시작했는데 잘 살렸넼ㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=1m51s">1:51</a> 진짜 뻥안치고 요즘 제일 핫한 브랜드들만 다 입었는뎈ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '왜 거울치료 효과가 없는 거죠?',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=08m05s">08:05</a> 주우재도 사람이었다1<br><a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=18m55s">18:55</a> 강사선생님 살짝 늦게 들어오는 거 국룰<br><a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=19m00s">19:00</a> 주우재도 사람이었다2',
#  '오랜만에 링피트 한다고 옛날에 링피트 할 때 입던 그 충격의 개얇은 브이넥 회색티 굳이 찾아 입는게 개애킹받네',
#  '2대 침착맨은 주우재가 맞는 것 같다',
#  '둘다 너무 이상행..',
#  '주우재 폼 미쳤다',
#  '올해 본 영상중에 제일 웃기다 ㅋㅋㅋㅋ',
#  '주우재는 이광수급의 예능 거물이 될 수 있는 자질을 가지고 있다.',
#  '혹은 그 이상',
#  '거대한 자질을 가진 주우재',
#  '거물 자질을 가진 주우재',
#  '@아아어 아무 부끄럼 없이 내 자질을 보여줬지',
#  '@아아어 😮',
#  '이거 풀버전 보면 골넣도 세레모니한다고 3분동안 지랄함 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '대체 이게 뭐하는 방송인데....',
#  '주우재 가라르폼 ㅋㅋㅋㅋㅋ',
#  '맨날 사람들이 별것도안닌걸로 킹받아 킹받아 하는거 보고 뭐가 킹받는다하는거야 개오바..<br>이랬는데 <br><a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=3m00s">3:00</a> 주우재씨가 준 신발 신고 <br>이거 내꺼다  이거내꺼네ㅋ 하는게  개킹받넹ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅌㅋㅋㅋㅋㅌㅌㅇㅇㅇㅇㅇㅇㅋㅋㅋㅋㅋㅋ아씤ㅋㅋㄴㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ진짜중학교때 까불까불친구보는거같고너모귀엽..<br>다들 이런마음으로 사랑과애증(?)의마음으로 킹받는다는다하는건갘ㅋㅋㅋㅋ',
#  '근데 이집엔 천만원 짜리 코트 걸이도 있네요',
#  '가디건 이쁘다',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=20m50s">20:50</a>  명짤의 탄생 <br>커뮤니티에서 보니깐 일본 애니 여주 같다고 하던데 그말이 딱이다 ㅋㅋㅋㅋㅋㅋ',
#  '말 그대로 미러전ㅋㅋㅋㅋㅋㅋ<br>우리 개방장을 방장같은 방식으로 킹받게 하는 사람은<br>세상에 주우재밖에 없는 거 같다ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '침 오늘 왤케 잘생김',
#  '주우재 저렇게 골무 뒤집어쓰고 파닥거리니까 둘리에 나오는 꼴뚜기 왕자 같네',
#  '게스트분들 중에 방장과의 케미는 그냥 우재씨가 일등이오',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=23m08s">23:08</a> 하이라이트',
#  '우재 졸귀다',
#  '이번편 감히 말씀드리는건데 &#39;레전드&#39; 입니다.',
#  '최고의 한국인',
#  '난 늘 흰티가 젤 궁금하더라',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=12m15s">12:15</a> 미친 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '침착맨은 주우재와의 합방을 두려워합니까?',
#  '미안하다 똥 싸느라 늦었다.',
#  '진짜 킹받는다 ㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=11m13s">11:13</a> 개웃겨 진짜 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '밍키타는거 졸귀',
#  '이거 원본 왜 없어요??',
#  '다음부턴 게이밍슈트 입기전에 꼭지에 반창고 붙여주세용',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=10m20s">10:20</a>침저씨 달려나가는거 왜케 귀여워 ㅋㅋㅋㅋㅋ',
#  '링피트 프로게이머 우재쿤이 진정한 2대 침착맨이다',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=10m20s">10:20</a>',
#  'ㅋㅋㅋ썸넬+ 오프닝 콤보 욕나오게 웃기네ㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅇㄴ 왤케 잘 맞아 둘잌ㅋㅋㅋㅋㅋㅋㅋ',
#  '인트로 왤캐기괴함 ㅋㅋㅋㅋㅋ',
#  '젊은 침착맨 ㅋㅋㅋㅋㅋ',
#  '발박수 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '달리는 폼 왤캐 익숙한가 했는데<br>희민이는 12살 썸네일이잖아ㅋㅋㅋ',
#  '비슷한데 다르게 킹받네 ;;',
#  '이게 대체 무슨 방송이지..',
#  '서로 참 좋은거 가르친다 ㅋㅋㅋ',
#  '우재형 사랑해요',
#  '잘생긴 얼굴과 큰키 <br>썪은 몸통과 개열받는 말투 <br><br>그냥 젊은 침착맨',
#  '나이차이도 얼마 안나서 그냥 키크고 마른 침착맨임',
#  '우재님은 잘생겨서 다행이네요..',
#  'ㅋㅋㅋㅋㅋㅋㅋ인트로 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ미쳣냐고 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '요즘 지떨코에 꽂혔네',
#  '우재님 목걸이 아시는분 있나용',
#  '센소라마',
#  '지옥이 있다면 이런곳일까..',
#  '이게 무슨 ㅋㅋㅋ이런걸 미러전이라고 하나요? ㅋㅋㅋ',
#  '진짜 존나웃걋음',
#  '이거 노딱 안 받나요?',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=16m44s">16:44</a> 반칙하고 지는 침하다 추착맨',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=08m55s">08:55</a> ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '세레모니부터 진짜 개웃었다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '이 두명이 3살 차이라는게 믿어지십니까?',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=27m03s">27:03</a>  힘든싱어 이지랄 ㅋㅋㅋㅋㅋ',
#  '카페에서 보다가 브이넥 입은거 보자마자 황급히 화면 끔;;',
#  '배트맨과 로빈',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=3m26s">3:26</a> 침착맨이 이 화법이 직원이 쓰면 사람들이 산다는 화법이잖아 ㅋㅋㅌㅌㅌㅋㅋㅌ',
#  '인트로부터 난장판이넼ㅋㅋㅋ',
#  'ㅂ ㅕ ㅇ ㄱ ㅓ ㄴ 티비 수위 실화냐',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=16m45s">16:45</a> 자연스럽네 ㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋ광인들 끼리 제대로 만남',
#  '챔퓌풘',
#  '남자 여자 모두 만족시키는 몇 안되는 유튜버',
#  '쓸데없이감미롭네',
#  '진짜 개열받는다 와 ㅋㅋㅋ',
#  '이제 링피트는 얼마나 기괴하게 하나 대결이 되는건가..',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=10m06s">10:06</a> 주멘~~~~~~~~~~~~~~~~~!',
#  '이게 올라오네 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '우재씨 왜 이미지 포기하는거예요??<br>원래 이런가여 ㅋㅋㅋㅋ',
#  '이제와서 유명해졌을 뿐 그는 꾸준히 돌아이였읍니다',
#  '침형이랑 놀아주러 주기적으로 방문하는 우재민수 감사하다',
#  '점점 잘생겨지네 침착맨',
#  '침착맨 주변에 모이는 사람들은 얼핏 겉모습은 멀쩡할지라도 다 이유가 있어서 곁에 모여드는 것이다',
#  '영웅은 영웅을 알아보는 법',
#  '이게 맞음',
#  '끼리끼리 ㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ앜ㅋㅋ',
#  '우재야 잘싸라',
#  '친구란 두개의 몸에 깃든 하나의 영혼..<br>그게 침과주는 아닐까',
#  '개방장 절대 안지네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '지디?',
#  '주우재가 침착맨 너무 좋아하는거 같다.',
#  '거울치료 ㅅㅂ ㅋㅋㅋㅋ',
#  '이게 무슨 방송 컨셉이야 ㅋㅋㅋㅋ',
#  '아저씨 둘이 왤캐 기여워?🤣🤣🤣',
#  '채팅창에 자꾸 “왜저래” 뜨는게 개웃김ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ근데 빈폴뇌절부터 나도 계속 왜저래 하면서 봄ㅋㅋㅋㅋ',
#  '앞으로 누군가 &#39;미러전&#39;이라는 뜻을 모른다하면 이영상을 틀어주십시오..',
#  '진짜 개 재미나게 놀다 갔네 나도 가서 놀고 싶음...ㅋㅋㅋㅋㅋㅋㅋ',
#  '👍👍👍',
#  '진짜 주우재님 몰랐는데 엄청 유쾌하고 재밌으신거 방장보고 알았습니다ㅋㅋㅋ  너무 꿀잼',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m32s">8:32</a> 자막으로 계속 가려주는거 개웃기네 ㅋㅋㅋㅋㅋㅋ',
#  '아 우재한테 옷입히기 당하고싶다',
#  '어쩌면 3대 침착맨이 될 사람일지도..?',
#  '진짜 슈퍼 똥참 러닝과 하이퍼 가라 모드 주우재는 전설이었다...',
#  '초록색 가디건 정보 아시는분 댓글 부탁드려요 제발 ㅠㅠㅠ',
#  '아더에러 같은데',
#  '주우재 태권도 다니는 개초딩같음',
#  '주우재님 목걸이 어디껀지알랴주세요   ,,,, 제발,,,,,',
#  '@장준희 감사합니다 가격보고 뒤로가기 했습니다',
#  '센소라마',
#  '방장 맨투맨 정보 아시는분 !!!',
#  '원본에 없는 이유라고 생각했던 부분이 편집본 초반부에 있어서 좋은데 혼란스럽네',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m32s">8:32</a> <br>자막으로 어떻게든 꼭G 가리려는 침수자의 노력...',
#  '우재쿤은 몸이 길어서 장기도 긴가요?<br>그래서 똥싸기가 힘든건가요?',
#  '친해지니까 꿀잼이네ㅋㅋㅋ',
#  '거울이었다.',
#  '패션의 완성은 얼굴이라는걸 다시 체감하고 갑니다.',
#  '어차피 님들 다 원본 보고 온 거 아는데 이건 진짜 원본 봐야됨',
#  '@김현동 침플에 풀영상 ㄱ',
#  '그게 없자너',
#  '룩딸로 웃기는것도 재주여~ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '침님은.. 광고한 브랜드에 대한 예의가 있네요~',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=26m55s">26:55</a>',
#  '강아지귀여워요',
#  '썸네일 진격의 거인같네',
#  '레깅스 도라지핏 킹받네 ㅋㅋㅋㅋㅋ',
#  '인트로로 갬성 뮤직비디오 한 편 제대로 뽑았네 ㅋㅋㅋㅋ',
#  '선물 고민한게 느껴지네.. 딱 어울릴만한것만  골라옴',
#  '초록카디건 브랜드 어디꺼래여????',
#  '이래야 부자되는구나',
#  '진짜 주우재 침착맨 젊은 버전 다됐네 ㅋㅋㅋㅋㅋ<br>침형 주우재형과 같이있을 때 심심할 일 없겠다',
#  '근대 3살 차이 밖에 안남 ㅋㅋ',
#  'ASK맨이 잃어버린 동생을 찾았다고 해서 왔습니다',
#  '시발 황혼의 뒤틀린 V넥 ㅋㅋㅋ',
#  '우재쿤 차마 부른거 보고 오 잘한다 이래서 갑자기 듣고싶어서<br>성시경 차마 라이브 듣고왔는데 사실상 다른 노래였네ㅋㅋㅋㅋㅋㅋㅋㅋㅋ<br>그래도 우재쿤 목소리 좋아서 듣기 좋았따!',
#  '진짜  둘이 왜그러니  ㅎㅎ',
#  '우재쿤.. 침착맨화 되가면… 너무 감사합니다',
#  '침부선 ㅋㅋㅋ',
#  '잘생긴 사람 둘이서 보드게임 이기고 세레머니는 프리미어리그 급 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=6m05s">6:05</a>',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '침착맨 존잘을 가리려면 저정도 패션은 돼야 하는구나...',
#  '@지나가던사람 저렇게 입어도 한남(나포함)들보다 잘생긴거 맞긴함',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'G DRAGON KING ,,,',
#  '😢',
#  '@침착맨이남친인꿈꿈 그 꿈은 왜 꾼거야?',
#  '자막으로 가리는 디테일 레전드',
#  '도플갱어끼리 만나선 안되는 이유',
#  '데프트임?',
#  '쇼츠보고 원본박물관을 찾아봤지만 없어서<br>기다리고 있다가 썹넬보고 싱글벙글 달려온사람 개추',
#  '플러스에있습니다만',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m04s">8:04</a> 침착맨 옷 벗은거 뒤늦게 보고 빵터지는거 개웃기네 진짜 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋ 아 ㅠ 오늘 차여서 징징 울다가 알림떠서 들오왔는데 바로 웃음 ㅠ ㅠ 알라뷰 침아저씨 알라뷰 우재쿤',
#  '화이팅이야~~~~~~',
#  '왜 차였나요?',
#  '방장 레깅스는 내복인가요?',
#  '주시경은 조선말 개화기에 우리말과 한글을 과학적으로 연구한 국문학자이자 언어학자이다. 전문적인 이론 연구를 통해 한글 표준화를 추진하였고 후진양성과 더불어 민족자주 차원에서 한글 보급운동을 펼치며 한글의 대중화와 근대화에 노력한 개척자이자 선각자였다.',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=8m07s">8:07</a> &quot;저항없는 웃음&quot;',
#  '댄져러스맨이병건',
#  '주우재랑 유희관 선수랑 동갑이라니...<br>칼든강도는 또 이들보다 4살이 어리다니...',
#  '찾아보니 전무님이랑 띠동갑인 메이트리(아카펠라 그룹)...',
#  '새삼 놀랍네요 가터벨트',
#  '졸라 결 잘맞어 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '주우재님 링피트하는거 뭔가,,,정자가 헤엄치는거 같아요',
#  '미친ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '거지 넝마를 주워와서 줘도 빈폴이랑 겹친다며 거절할지 궁금합니다',
#  '방장 뱃살 출렁이는 거 봐 ㅋㅋㅋㅋㅋ',
#  '이게 현대예술이지',
#  '가라로 하는거 개 킹받음 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '개열받네',
#  '어우 보기 좋아',
#  '개못해 개방장',
#  '초록색 가디건 정보 알 수 있을까요 ??',
#  '아니 뭔ㅋㅋㅋㅋ 나는 떡을썰태니 넌 붓글씨를 쓰거라도 아니고 ㅋㅋ콜라보 미친ㅋㅋㅋ',
#  '우재쿤 똥만때리지말고 개방장도 좀 때려주세요!!',
#  '똥으로?',
#  '너무 노출이 심해요',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=7m46s">7:46</a>  침착맨 갭모에',
#  '진짜 일요일 저녁 그 자체다.. 오늘 영상도 감사합니다',
#  '저녁식사 일찍 마치고 맘놓고 보는중 ㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=UWcgWLph_os&amp;t=21m49s">21:49</a> 달리는 거 진짜 열라 짜증 나 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '첫째 아들 침착맨<br>둘째 아들 주우재<br>막내 아들 박정민',
#  '미친놈같아 둘 다 ㄲㄱㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㄱㅋㄱㅋㅋㄱㅋㄱㄱㄱ키🥲',
#  '이게 무슨 인트로야 ㅋㅋㅋ 진짜 도저히 짐작할 수없다 ㅋㅋ',
#  '우재쿤 키 커서 서있으면 리버스침공되는거 뻘하게 웃김 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '어찌하여 &#39;몸&#39;만 오셨소...',
#  '역침공 ㄷㄷ',
#  '역준빈을 이은 리버스침공 ㅋㅋㅋㅋ',
#  '@monkey king 제발...',
#  '뻘? 근',
#  '아오 개방장 두명있는것 같아 평소엔 그냥 개열받는데 오늘은 개개열열받네 진짜',
#  '20받네 ㅋ ㅋ',
#  '그들만의 리그',
#  'ㅋㅋㅋㅋㅋㅋ 히든싱어 아닌 힘든싱어',
#  '참된 광고모델 ㅋㅋ 빈폴 선생님들은 좋겠네',
#  '미친 ㅋㅋㅋㅋㅋㅋ 이거 결국 보게되는구나 본채널에서',
#  '먼데 다 잘어울리냐 침착맨 책임지셈',
#  '주우재 가수임?',
#  '밥 먹는데 시작하자 마자 똥 얘기네 ㅅㅂ',
#  '히오스 레깅스와 회색 내복...눈호강 감사하다',
#  '침착맨과 긴착맨 합방 ㄷㄷ 드디어 본채널에서 나풀거리는 주우재님을 볼 수 있게 되었네요 영광입니다',
#  '솔직히 진짜 뻘짓인데 내 웃음코드가 이제 여기에 최적화로 프로그래밍 돼서 그냥 웃김',
#  '야 나두! ㅋㅋ',
#  'ㄹㅇㅋㅋ',
#  '아 이거구나 ㅋㅋ',
#  '썸네일만 보고도 똥과 오줌을 지려버렸다!!',
#  '류 vs 캔 .. 팔레트 스왑일뿐 본질은 똑같은 두사람',
#  '개방장 에어로빅 상하의 개열받음 진짜로 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '이게 바로 2032년 유툽을 이끌 방송이다',
#  'ㄹㅇ 이날 개정신없었음,,,',
#  '드디어 떳다 이건 최소 백만각임',
#  '이것이 바로 이이제이다',
#  '진짜 인트로만 봐도 어지럽다',
#  '우재쿤도 한 10년뒤엔 수염기르고 열받게 놀고 있을거같아',
#  '@김재영 우재 나이 존나 억지스럽긴 함.. 저 얼굴이 37??',
#  '??? 엄마가 친구 가려만나랬잖아!!!!',
#  'G DRAGON KING ,,,',
#  '진짜 병건이 형이네 ㅋㅋㅋ',
#  '우재쿤 10년 뒤에도 같이 놀자구',
#  '주우재 피들스틱이 링프트하는거같아 ㅋㅋㅋㅋㅋㅋㅋㅋ개웃기네',
#  '저 흘러내리는 운동복이 너무 킹받아 ㅋㅋ',
#  '올해의 인물 유력후보 ’주우재‘',
#  '사실상 따놓은 당상',
#  'ㅋㅋㅋㅋㅋ 인트로 역대급이네 존낭 ㅜ슽시엨ㅋㅋㅋ',
#  '뱃살 킹받네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '시작부터 혼란하다',
#  '잘생기고 노래도 잘부르고 키도 큰<br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>침착맨',
#  '30빠',
#  '1초부터 킹받게하네',
#  '썸네일 무쳤다 ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '내용을 짐작 할 수 없는 인트로',
#  '이날 진짜 레전드임',
#  '브이넥 골만큼 깊어진 둘사이 응원하겠습니다',
#  '착맨 마감하는 초밥장인 같다',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '아니 침투부 에서 왠 감미로운 목소리가나오나 했네',
#  '아 엄마 이것만 보고 숙제 한다고',
#  '19금 걸어야하는 거 아님?',
#  '폼 미쳤다',
#  '드디어 나왔다 내 저녁',
#  '주우재씨 왜 노래도 잘불러',
#  '인트로 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ무슨 조합이지 이게',
#  '<b>멀리서 보면 개방장이고 가까이서보면 주우재다.</b>',
#  '@JAKE 코난이냐?ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '그니까 그게 양자역학인가요?',
#  '거리상 실제로 그렇잖아 ㅋㅋㅋㅋ',
#  '@JAKE 왜 몸을 하나로 붙이냐고 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '@JAKE 반대 아님?',
#  '저녁상 차려놓고 틀었는데 시작하자마자 똥얘기……',
#  'ㅋㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 즐겁다',
#  '그냥 주우재는 럭키 침착맨임 ㅋㅋㅋㅋ',
#  '쑤빠라끼맨',
#  '???: 나한테 운으로 붙으려고 하지 마세요',
#  '그럼 주우재는 럭키럭키 침착맨이라고하자',
#  '럭키로 따지면 침착맨이지',
#  '주우재 인생사 들어보면 ㄹㅇ 럭키맨..',
#  '브이넥 개 열받네...',
#  '악',
#  '아오 진짜 저 게이밍 슈트 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '침부선',
#  '동대문 옷 상가에 있는 화장한 옷집 주인 아저씨 같이 생김ㅋㅋㅋㅋㅋ',
#  '게이밍수트 레전드',
#  '인트로부터 어지럽네',
#  '광인들의 파티 좋네요',
#  '옘병 떨죠',
#  '와 뮤직비디오',
#  '썸네일만 봐도 웃기네 ㅋㅋㅋㅋ',
#  '와!',
#  '침착맨을 흥하여라 <a href="http://www.youtube.com/results?search_query=%23%EA%B5%AC%EB%8F%85">#구독</a><a href="http://www.youtube.com/results?search_query=%23%EC%A2%8B%EC%95%84%EC%9A%94">#좋아요</a>',
#  '1',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=7m13s">7:13</a>!***<br><a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=10m33s">10:33</a>!!**<br><a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=14m38s">14:38</a>!?***',
#  '설탕국수 모르는 사람 많구나 저기에 +열무김치 올려먹으면 3그릇 뚝딱인데 착형 꼭 먹어주세요',
#  '다못한 게시판에서조차도 다 못한 게시글을 모아놓은 다못한 게시판 다못한 게시판 컨텐츠는 어떤가요?',
#  '나비고기는 나비 1도 안닮았는데 닮았다고 하고 전갈한테는 사람 정수리에 엄청 긴 팔이 달린것같다고 하고 어우 열받아 T1경기져서 아쉬운데 이게 이열치열??',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=10m10s">10:10</a> 이렇게먹는사람이 또 있었다니.. 사연도 나랑 똑같다...<br>라면끓여와서 물을 받아놓은 밥그릇에 메밀면 담가먹듯이 맹물에 면담가먹는건데ㅋㅋㅋㅋ 오늘 저녁이거닷',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=1m15s">1:15</a> 침수자야 고맙다...',
#  '자 오늘은 다 못한 다못한게시판 게시판 보도록 하겠습니다~',
#  'ㅋㅋ쮸이쮸이 개웃겨',
#  '침튜브 근 한달 본것중에 젤 재밋네요',
#  '피터파커세요? 벌이는 비슷합니다 ㅋㅋㅋㅋㅋㄱㅋㅋㅋㅋㅋ 어엌ㅋㅋㅋㅋ',
#  '혹시 피터파커세요?<br>벌이는 비슷합니다.<br><br>ㅋㅋㅋㅋ 여기서부터 펑 터졌음 ㅋㅋㅋㅋㅋ',
#  '🛑 트위 터 에서도 유명-  - &gt;&gt; 👿👿\r<br>\r<br> &#39;유; 튜 ;브  보 # 예# 노 # 지  영상 맛보기지림  👿👿🛑',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=12m01s">12:01</a> ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '시츄 너무 귀여워 시츄보고 들어옴',
#  '읽는 속도 맞춰서 파란색으로 바꿔주는 거 진짜 대단하다',
#  '애완동물 다음편 포기했는데 이게 나오네 최고다..',
#  '이 날 왤케 잘생김',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=9m27s">9:27</a> 비주얼 ㅁㅊㅋㅋㅋㅋㅋㅋㅋㅋㅋ 곰팡이 핀줄 알았네요',
#  '밥먹으면서 침투브 보면 <br>꼭 똥 얘기 나오고 비위 상하는 얘기 나옴',
#  '얼굴이 상디가 됐네',
#  '순간 그림 왜케 잘그리지????? 했는데 만화가였음.......',
#  '쮸이쮸이 첫번째 사진 사람 그림자가 등산하는 모습이랑 비슷함',
#  '오늘 침 패션은 화이트색 티셔츠에 베이지색 팬츠를 매치함으로 편안한 색감과 아메리칸 캐주얼 느낌으로 깔끔한 룩 이군요 거기다가 귀여운 새 그림으로 포인트를 주면서 자신이 강한 존재라는걸 보여주는 센스있는 룩이네요',
#  '다보탑 게시판 ㄷㄷㄷ..',
#  'zzzzzzzzzzzzzzzzzzzzzzzz똑같은 내용이라도 침착맨이 읽으면 치트임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=12m24s">12:24</a>',
#  '역시 천-재',
#  '밥 먹을때 보려고 딱 틀었는데 바로 거미등장..',
#  '프로틴충은 콩팥 진심 걱정되는데 병원 검사 한번 받아봐야할듯',
#  '썸네일 종수보고 들어왔다',
#  '직전에 혼자 먹은 쌍쌍바 짤렸네 개웃겼는데ㅋㅋㅋㅋㅋ',
#  '이런 사람냄새 나는 시청자 참여 컨텐츠 너무 좋다 이말이야~',
#  '사랑해요❤',
#  '헐 우리 토리쉑 썸네일까지 타다니.. 나보다 잘나가길 바란건 아니였어..',
#  'ㅋㅋㅋㅋ오랜만에 짬통꺼내는 컨텐츠 좋다',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=7m07s">7:07</a> 그림자 분신술<br><a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=12m23s">12:23</a> 간장 1톤 요지랄크크<br><a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=13m30s">13:30</a> 미@친놈',
#  '와 오늘 중국요리집가서 매운오징어 팔길래 주문했는데 2시간 걸리던데 저렇게 잡으러 간 가게였구나...(결국안나옴)',
#  '어묵이 많어 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '거미 사진 전에 미리 미방 깔아주셔서 감사해요',
#  '헐 물라면 개공감ㅋㅋㅋㅋㅋㅋ 저 맵찔이에 짠거 싫어해서 물에 씻어먹거나 우유 말아머거요 ㅋㅋㅋㅋ',
#  '마우스로 강아지 엄청 잘그린다 ㅋㅋㅋㅋ 역시 전 만화가',
#  '개방장도 보면 참 댕댕이 좋아함 ㅋㅋㅋ',
#  '다 못 한 이란 제목이랑 타투 썸네일이 있길래 아 타투를 완성하지 못한 그런 사람들이 나오나 보다 했는데ㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '오징어 산지직송이네ㅋㅋㅋㅋㅋㅋ',
#  '프로틴가루 저분은 진짜 미쳤네..... 심한말 나옴ㅋㅋㅋㅋ',
#  '저희 본가가 전라남도인데 전라도에선 설탕국수라고 해서 보리차에 국수 말고 설탕 좀 넣어서 먹습니다. 주로 일하다 새참으로 먹거나 손님한테 내주는 음식이였는데 요즘은 설탕국수 대신 콩국수에 설탕 넣어서 먹어요. 그래서 전라도쪽 중국집같은데서 콩국수 시키시면 설탕이랑 같이 나와요. 팥죽이나 팥칼국수에도 설탕 넣어 먹는데 은근 안알려지긴 했죠.',
#  '침착맨 달팽이 너무 귀엽네요 영상 아직 남아있나욤',
#  '글에 색깔칠해주는 침수자님들.. 정말 감사하다..',
#  '침착맨이 웃으면 나도 찐으로 행복해진다ㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=12m22s">12:22</a> 담백하게 읽어나가는게 ㅈㄴ웃기넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '후반에 신타6로 짬통밥은 돈 버린거 대박이네... 신타6가 가격이 비싼편인데 저걸 저렇게 만들다니;',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=5m32s">5:32</a> 침착맨 하트 2번 ♡♡',
#  '맛있다.',
#  '침착맨이 미술하는거 보고 싶다~ 정물화 같은~',
#  '물라면 ㄹㅇ 맛있는데 고소하고 ㅋㅋ',
#  '마지막에 지나가는 털보야가 개웃기네 ㅋㅋㅋㅋ',
#  'Unfinished business',
#  '아 머리 킹받네',
#  '방훈수 컨텐츠 해줘잉',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=12m03s">12:03</a> 노잼드립에 엄격한 개방장의 엄중경고',
#  '다못게 계속 만들어줘잉',
#  '설탕라면 예고',
#  '시청자게시판 자주해줘잉',
#  '토크형식으로 구독자수가ㅜ 이분이 이렇게 대단한분인지 미처 모름ㅜ',
#  '물라면 진짜 맛있는데',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=5m19s">5:19</a> 아씨 지하철에서 무방비하게 보다가  터졌네ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=7m21s">7:21</a> 그림자인줄 알았네요',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=13m30s">13:30</a> 진짜 개열받네 ㅋㅋㅋㅋㅋㅋ<br>진짜 헬창들은 혓바닥이 맛이 가버렸나 ㅋㅋㅋ',
#  '방장 동물얘기할때 뭔가 츤츤 넘 커엽고 좋음ㅋㅋㅋ',
#  '진짜 짬을 모아서 밥을 만들었는데 오히려 재밌어..',
#  '재밌게 잘 보고 있습니다. 감사합니다~',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=7m28s">7:28</a><br><a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=7m54s">7:54</a>',
#  '시츄 주인 좋겠다 썸네잏빅제',
#  '좋아서 다시보기에 원본에 편집본까지 쥰내 돌려보는중입니다 ㅎ_ㅎ',
#  '안녕',
#  '다 못 한 게시판에서 다 못 한 게시글을 모으는 다다 못 한 게시판도 있나요?',
#  '설탕국수 집에서 여름마다 맨날 먹는 건데',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=7m01s">7:01</a> 베개에 복자 뭐지ㅋㅋㅋㅋ',
#  '설탕국수 존버합니드',
#  '전갈맨 ㄹㅇ 으악이다',
#  '절대 팬아트 둘러보기해줘잉',
#  '혹시 다못한 게시판의 다못한 게시판도 나올까요? 아니면 이날 다봤나요?',
#  '궤도보다 음쓰를 잘 만드는 개방장 감사하다',
#  '재미있다 히히',
#  '물라면 많이 먹어봄 최대한 짜게 끓여서 찬물에 행궈먹으면 먹을만함',
#  '애가 뭔가 믹스냄새난다는거ㅋㅋㅋㅋㅋㅋ 뭔가 무례하게보일수있는말인데 방장이말하니까 나쁜뜻아닌거알겠고 걍 웃김ㅋㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=3m37s">3:37</a> 볼트론 등장',
#  '딸을 위해 간장 1톤 물 1톤 길으러 가는 침청자들',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=10m51s">10:51</a> 호주산 와규?',
#  '다음 거는 다 못한 게시판에 다 못한 게시판이겠네',
#  '나는 이런영상이 제일 조아',
#  '유통기한 지나기 전에 몰아 먹는 침마카세!!?? 오히려 좋앙',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=12m25s">12:25</a> 단위가 갑자기 1톤이라 배 찢어지는 줄 알았네 ㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=5m45s">5:45</a> ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '공소시효까지 살뜰히 챙겨주는 침착맨 너무 서윗해잉~',
#  '아니 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 닉네임부터 글 내용까지 완벽하네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진짜 본인이네 ㅋㅋㅋ',
#  'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ어묵빌런 본인이잖슴~~',
#  '시츄는 1년 존버 했다가 끝내 썸네일까지 올라왔네 ㅋㅋ',
#  '쉽지 않았어요 😔',
#  '침착맨 그는 신인가?보약인가?  나무위키만 읽어도 영상이 만들어지고 짬통을 엎어도 영상이 만들어지고 입만 열었다하면 재밌다<br>이 남자 도대체 멀까?<br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>ASK맨',
#  '다다못한게시판은 없나요?? ㅜㅜ',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=5m40s">5:40</a> 진짜 여기서부터 숨도 못쉬고 1분은 웃었다ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '진짜 개징그럽ㅋㅋㅋㅋㅋ',
#  '개방장 따라서 다 은은하게 미쳐있어 ㅋㅋㅋ',
#  '다 못한 게시판의 다못한 게시판 부탁드립니다',
#  '앵두 생긴거 귀엽다 하자마자 지랄맞대ㅋㅋㅋㅋㅋㅋ',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=13m30s">13:30</a> 헛소리를 차마 다 읽지 못하고 욕을 입에 담는 침착맨',
#  '침착맨 마리오 오디세이하고 종이마리오 한적있지 않나요? 찾아봤는데 안나오길래..',
#  '이렇게 소소한 저챗 재미 너무 좋아여',
#  '다못한 게시판에서 못본 게시판을 또 컨텐츠로 뽑을거라는거네 그럼 다못한 다못한 게시판에서 못본 게시판을 또 컨텐츠로 뽑고 다못한 다못한 다못한 게시판에서 못본 게시판을 또 컨텐츠로 뽑고 다못한 다못한 다못한  게시판에서 못본 게시판을 또 컨텐츠로 뽑고 무한동력 ㄷㄷ',
#  '파란색으로 글씨 바뀌는거 은근 불편하넹',
#  '한솥프로틴락토프리우유 진짜 못참아주겠다',
#  '짬처리 오히려 좋아<br>이번주 침마카세 안바뀌는것도 오히려 좋아...<br>일주일내내 잘때 틀어놓고 잤더니 오늘 70분동안 동네 구보하고 영상보면서 맨손스쿼트 50개 함....<br>이러다가 단백질가루 비빔밥 먹게될지도.....',
#  '침착맨영상 갈아서 가루침착맨으로 드시는 수준이네',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=3m46s">3:46</a> 가운데는 코끼리 미쳤나봐 진짜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㄱㅋ',
#  '이제 다못한거 또 다못한 게시판 나오나요',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=13m32s">13:32</a>',
#  '침 카페는 커뮤니티  따로 만들어도 좋을듯 디시 스럽지만 선은 침이 칼 같이 지키고 있어 나름 편향적 클린함',
#  '다 못본 게시판에서 다 못보면 어디로 가죠?',
#  '<a href="https://www.youtube.com/watch?v=EN8umXVj-YA&amp;t=1m24s">1:24</a> 벌이는 비슷하대 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ <br>센스 지렸다',
#  '윤담백인줄',
#  '쮸이쮸이 개귀엽누 ㅋㅋㅋㅋㅋ',
#  ...]
